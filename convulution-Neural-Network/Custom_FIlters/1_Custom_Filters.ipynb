# %% [markdown]
# ## Creating a FIlter and Edge Detection

# %% [markdown]
# ### Import resources and display Image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image = mpimg.imread('curved_lane.jpg')

plt.imshow(image)

# %% [markdown]
# ### Convert the image to gray-scale

# %%
# Convert to gray scale for filtering

gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### SOBEL FILTER
# The Sobel filter is very commonly used in edge detection and in finding patterns in intensity in an image. Applying a Sobel filter to an image is a way of taking (an approximation) of the derivative of the image in the x or y direction, separately. The operators look as follows.
#
# <img height="1px"  src="https://user-images.githubusercontent.com/24764528/50733511-dd886600-11b4-11e9-8674-e748621f6fc0.png"/>

# %%
# Creating Custom Filter

# SOBEL FILTER
sobel_y = np.array([[ -1, -2, -1],
           [0,0,0],
           [1, 2, 1]])

sobel_x = np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)
filtered_image_Y = cv2.filter2D( gray, -1, sobel_y)
filtered_image_X = cv2.filter2D( gray, -1, sobel_x)



print(" OUTPUT BY SOBEL-X")
plt.imshow(filtered_image_X, cmap = 'gray')
# Out:
#  OUTPUT BY SOBEL-X

# %%
print(" OUTPUT BY SOBEL-Y")
plt.imshow(filtered_image_Y, cmap = 'gray')
# Out:
#  OUTPUT BY SOBEL-Y

# %%
# Creating a 5x5 Filter
Filter_random = np.array([[0, 0, -1, -1, 0],
                          [0, 1.2, -2.2, 0, 0],
                          [0, -2.2, 12.8, -2.2, 0],
                          [0, 1.2, -2.2, 0, 0],
                          [0, 0, -1, -1, 0],
                         ])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)
filtered_img = cv2.filter2D( gray, -1, Filter_random)




plt.imshow(filtered_img, cmap = 'gray')
